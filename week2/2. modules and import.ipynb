# %% [markdown]
# # Модули и импорт

# %% [markdown]
# ##### sys.modules - словарь (имя модуля: model obj), в котором хранятся имена вызываемых модулей. Если имя уже находится в словаре, то исполнения файла с ним не происходит.

# %% [markdown]
# ##### Пример рыботы со словарем модулей:

# %%
import sys
print(type(sys.modules))
print(sys.modules)
# Out:
# <class 'dict'>
# {'IPython.core.formatters': <module 'IPython.core.formatters' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\IPython\\core\\formatters.py'>, 'IPython.lib.backgroundjobs': <module 'IPython.lib.backgroundjobs' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\IPython\\lib\\backgroundjobs.py'>, 'pkg_resources._vendor': <module 'pkg_resources._vendor' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\setuptools-20.3-py3.5.egg\\pkg_resources\\_vendor\\__init__.py'>, 'jupyter_client.jsonutil': <module 'jupyter_client.jsonutil' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\jupyter_client\\jsonutil.py'>, 'jupyter_client.blocking.channels': <module 'jupyter_client.blocking.channels' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\jupyter_client\\blocking\\channels.py'>, 'ipykernel.serialize': <module 'ipykernel.serialize' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\ipykernel\\serialize.py'>, 'IPython.lib.clipboard': <module 'IPython.lib.clipboard' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\IPython\\lib\\clipboard.py'>, 'sre_parse': <module 'sre_parse' from 'C:\\Program Files\\Miniconda3\\lib\\sre_parse.py'>, 'decorator': <module 'decorator' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\decorator.py'>, 'pkg_resources.extern.packaging.version': <module 'pkg_resources.extern.packaging.version' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\setuptools-20.3-py3.5.egg\\pkg_resources\\_vendor\\packaging\\version.py'>, 'logging.handlers': <module 'logging.handlers' from 'C:\\Program Files\\Miniconda3\\lib\\logging\\handlers.py'>, 'pickleshare': <module 'pickleshare' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\pickleshare.py'>, 'zmq.backend.cython.message': <module 'zmq.backend.cython.message' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\zmq\\backend\\cython\\message.cp35-win_amd64.pyd'>, 'pkg_resources._vendor.packaging.__about__': <module 'pkg_resources._vendor.packaging.__about__' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\setuptools-20.3-py3.5.egg\\pkg_resources\\_vendor\\packaging\\__about__.py'>, 'ntpath': <module 'ntpath' from 'C:\\Program Files\\Miniconda3\\lib\\ntpath.py'>, 'IPython.core.excolors': <module 'IPython.core.excolors' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\IPython\\core\\excolors.py'>, 'traitlets': <module 'traitlets' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\traitlets\\__init__.py'>, 'zmq': <module 'zmq' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\zmq\\__init__.py'>, 'ipython_genutils._version': <module 'ipython_genutils._version' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\ipython_genutils\\_version.py'>, 'enum': <module 'enum' from 'C:\\Program Files\\Miniconda3\\lib\\enum.py'>, 'IPython.utils.tokenutil': <module 'IPython.utils.tokenutil' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\IPython\\utils\\tokenutil.py'>, 'IPython.core.magic': <module 'IPython.core.magic' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\IPython\\core\\magic.py'>, 'posixpath': <module 'posixpath' from 'C:\\Program Files\\Miniconda3\\lib\\posixpath.py'>, '_sqlite3': <module '_sqlite3' from 'C:\\Program Files\\Miniconda3\\DLLs\\_sqlite3.pyd'>, 'linecache': <module 'linecache' from 'C:\\Program Files\\Miniconda3\\lib\\linecache.py'>, 'getpass': <module 'getpass' from 'C:\\Program Files\\Miniconda3\\lib\\getpass.py'>, 'traceback': <module 'traceback' from 'C:\\Program Files\\Miniconda3\\lib\\traceback.py'>, 'encodings.latin_1': <module 'encodings.latin_1' from 'C:\\Program Files\\Miniconda3\\lib\\encodings\\latin_1.py'>, 'pkg_resources._vendor.six': <module 'pkg_resources._vendor.six' from 'C:\\Program Files\\Miniconda3\\lib\\site-packages\\setuptools-20.3-py3.5.egg\\pkg_resources\\_vendor\\six.py'>, 'keyword': <module 'keyword' from 'C:\\Program Files\\Miniconda3\\lib\\keyword.py'>, '_string': <module '_string' (built-in)>, '_imp': <module '_i ...

# %% [markdown]
# ##### Задача

# %%
import datetime

date_list = [int(i) for i in input().split()]

old_date = datetime.date(year = date_list[0], month = date_list[1], day = date_list[2])
new_date = old_date + datetime.timedelta(days = int(input()))

print(new_date.year, new_date.month, new_date.day)
# Out:
# 2016 12 20
# 61
# 2017 2 19
